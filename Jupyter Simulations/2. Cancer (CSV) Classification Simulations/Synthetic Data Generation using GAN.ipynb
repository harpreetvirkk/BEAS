# %%
# !pip install ctgan
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ctgan
#   Downloading ctgan-0.2.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy<2,>=1.17.4 in /Library/Python/3.8/site-packages (from ctgan) (1.18.5)
# Collecting pandas<0.26,>=0.24
#   Downloading pandas-0.25.3-cp38-cp38-macosx_10_9_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 12.0 MB/s eta 0:00:01
# Collecting torch<2,>=1.0
#   Downloading torch-1.6.0-cp38-none-macosx_10_9_x86_64.whl (97.5 MB)
#      |████████████████████████████████| 97.5 MB 8.1 MB/s eta 0:00:012   |▏                               | 368 kB 2.9 MB/s eta 0:00:34     |████▌                           | 13.8 MB 699 kB/s eta 0:02:00     |█████▏                          | 15.6 MB 699 kB/s eta 0:01:58     |███████████▍                    | 34.7 MB 14.4 MB/s eta 0:00:05     |█████████████▌                  | 41.0 MB 14.4 MB/s eta 0:00:04     |██████████████                  | 42.8 MB 14.4 MB/s eta 0:00:04     |█████████████████▌              | 53.2 MB 27.2 MB/s eta 0:00:02     |███████████████████             | 57.6 MB 11.3 MB/s eta 0:00:04     |████████████████████            | 60.9 MB 11.3 MB/s eta 0:00:04     |█████████████████████▎          | 64.9 MB 14.9 MB/s eta 0:00:03     |████████████████████████████    | 85.5 MB 9.8 MB/s eta 0:00:02
# Collecting scikit-learn<0.23,>=0.21
#   Downloading scikit_learn-0.22.2.post1-cp38-cp38-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 8.0 MB/s eta 0:00:01
# Collecting torchvision<1,>=0.4.2
#   Downloading torchvision-0.7.0-cp38-cp38-macosx_10_9_x86_64.whl (387 kB)
#      |████████████████████████████████| 387 kB 11.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /Library/Python/3.8/site-packages (from pandas<0.26,>=0.24->ctgan) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Library/Python/3.8/site-packages (from pandas<0.26,>=0.24->ctgan) (2020.1)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 13.6 MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.11 in /Library/Python/3.8/site-packages (from scikit-learn<0.23,>=0.21->ctgan) (0.16.0)
# Requirement already satisfied: scipy>=0.17.0 in /Library/Python/3.8/site-packages (from scikit-learn<0.23,>=0.21->ctgan) (1.4.1)
# Requirement already satisfied: pillow>=4.1.1 in /Users/harpreetvirk/Library/Python/3.8/lib/python/site-packages (from torchvision<1,>=0.4.2->ctgan) (7.2.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas<0.26,>=0.24->ctgan) (1.15.0)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491056 sha256=48c4c96353738f28f1084e2344835df19b4a0a01493031a82757867bcbea81ff
#   Stored in directory: /Users/harpreetvirk/Library/Caches/pip/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
# Successfully built future
# Installing collected packages: pandas, future, torch, scikit-learn, torchvision, ctgan
#   WARNING: The scripts futurize and pasteurize are installed in '/Users/harpreetvirk/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx and convert-onnx-to-caffe2 are installed in '/Users/harpreetvirk/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script ctgan is installed in '/Users/harpreetvirk/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed ctgan-0.2.1 future-0.18.2 pandas-0.25.3 scikit-learn-0.22.2.post1 torch-1.6.0 torchvision-0.7.0

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
data = pd.read_csv('./data/data.csv')
del data['Unnamed: 32']

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 489    913535         M        16.69         20.20          107.10      857.6
# 490  91376701         B        12.25         22.44           78.18      466.5
# 491  91376702         B        17.85         13.23          114.60      992.1
# 492    914062         M        18.01         20.56          118.40     1007.0
# 493    914101         B        12.46         12.83           78.83      477.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760        0.300100              0.14710
# 1            0.08474           0.07864        0.086900              0.07017
# 2            0.10960           0.15990        0.197400              0.12790
# 3            0.14250           0.28390        0.241400              0.10520
# 4            0.10030           0.13280        0.198000              0.10430
# ..               ...               ...             ...                  ...
# 489          0.07497           0.07112        0.036490              0.02307
# 490          0.08192           0.05200        0.017140              0.01261
# 491          0.07838           0.06217        0.044450              0.04178
# 492          0.10010           0.12890        0.117000              0.07762
# 493          0.07372           0.04043        0.007173              0.01149
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 0           0.2419                 0.07871     1.0950      0.9053
# 1           0.1812                 0.05667     0.5435      0.7339
# 2           0.2069                 0.05999     0.7456      0.7869
# 3           0.2597                 0.09744     0.4956      1.1560
# 4           0.1809                 0.05883     0.7572      0.7813
# ..             ...                     ...        ...         ...
# 489         0.1846                 0.05325     0.2473      0.5679
# 490         0.1544                 0.05976     0.2239      1.1390
# 491         0.1220                 0.05243     0.4834      1.0460
# 492         0.2116                 0.06077     0.7548      1.2880
# 493         0.1613                 0.06013     0.3276      1.4860
#
#      perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  \
# 0           8.589   153.40       0.006399        0.049040      0.053730
# 1           3.398    74.08       0.005225        0.013080      0.018600
# 2           4.585    94.03       0.006150        0.040060      0.038320
# 3           3.445    27.23       0.009110        0.074580      0.056610
# 4           5.438    94.44       0.011490        0.024610      0.056880
# ..            ...      ...            ...             ...           ...
# 489         1.775    22.95       0.002667        0.014460      0.014230
# 490         1.577    18.04       0.005096        0.012050      0.009410
# 491         3.163    50.95       0.004369        0.008274      0.011530
# 492         5.353    89.74       0.007997        0.027000      0.037370
# 493         2.108    24.60       0.010390        0.010030      0.006416
#
#      concave points_se  symmetry_se  fractal_dimension_se  radius_worst  \
# 0             0.015870      0.03003              0.006193         25.38
# 1             0.013400      0.01389              0.003532         24.99
# 2             0.020580      0.02250              0.004571         23.57
# 3             0.018670      0.05963              0.009208         14.91
# 4             0.018850      0.01756              0.005115         22.54
# ..                 ...          ...                   ...           ...
# 489           0.005297      0.01961              0.001700         19.18
# 490           0.004551      0.01608              0.002399         14.17
# 491           0.007437      0.01302              0.001309         19.82
# 492           0.016480      0.02897              0.003996         21.53
# 493           0.007895      0.02869              0.004821         13.19
#
#      texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0            17.33           184.60      2019.0           0.16220
# 1            23.41           158.80      1956.0           0.12380
# 2            25.53           152.50      1709.0           0.14440
# 3            26.50            98.87       567.7           0.20980
# 4            16.67           152.20      1575.0           0.13740
# ..             ...              ...         ...               ...
# 489          26.56           127.30      1084.0           0.10090
# 490          31.99            92.74       622.9           0.12560
# 491          18.42           127.10      1210.0           0.09862
# 492          26.06           143.40      1426.0           0.13090
# 493          16.36            83.24       534.0           0.09439
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560          0.71190               0.26540          0.4601
# 1              0.18660          0.24160               0.18600          0.2750
# 2              0.42450          0.45040               0.24300          0.3613
# 3              0.86630          0.68690               0.25750          0.6638
# 4              0.20500          0.40000               0.16250          0.2364
# ..                 ...              ...                   ...             ...
# 489            0.29200          0.24770               0.08737          0.4677
# 490            0.18040          0.12300               0.06335          0.3100
# 491            0.09976          0.10480               0.08341          0.1783
# 492            0.23270          0.25440               0.14890          0.3251
# 493            0.06477          0.01674               0.02680          0.2280
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 489                  0.07623
# 490                  0.08203
# 491                  0.05871
# 492                  0.07625
# 493                  0.07028
#
# [494 rows x 32 columns]

# %%
discrete_columns = list(data.columns)
discrete_columns
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
data.isnull().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
from ctgan import CTGANSynthesizer

ctgan = CTGANSynthesizer()
ctgan.fit(data, discrete_columns, epochs=50)
# Out:
# Epoch 1, Loss G: 5.9212, Loss D: -0.0025
# Epoch 2, Loss G: 5.9411, Loss D: 0.0009
# Epoch 3, Loss G: 5.9597, Loss D: 0.0019
# Epoch 4, Loss G: 5.8886, Loss D: -0.0007
# Epoch 5, Loss G: 5.9364, Loss D: -0.0021
# Epoch 6, Loss G: 5.8507, Loss D: -0.0086
# Epoch 7, Loss G: 5.9535, Loss D: -0.0003
# Epoch 8, Loss G: 5.8636, Loss D: -0.0062
# Epoch 9, Loss G: 5.8325, Loss D: 0.0109
# Epoch 10, Loss G: 5.8941, Loss D: -0.0177
# Epoch 11, Loss G: 5.9591, Loss D: 0.0021
# Epoch 12, Loss G: 5.9165, Loss D: -0.0053
# Epoch 13, Loss G: 5.9803, Loss D: -0.0118
# Epoch 14, Loss G: 5.9453, Loss D: -0.0071
# Epoch 15, Loss G: 5.9260, Loss D: -0.0036
# Epoch 16, Loss G: 5.9218, Loss D: -0.0252
# Epoch 17, Loss G: 5.8679, Loss D: -0.0127
# Epoch 18, Loss G: 5.9222, Loss D: -0.0094
# Epoch 19, Loss G: 5.9263, Loss D: -0.0146
# Epoch 20, Loss G: 5.9205, Loss D: -0.0202
# Epoch 21, Loss G: 5.9831, Loss D: -0.0029
# Epoch 22, Loss G: 6.0108, Loss D: -0.0227
# Epoch 23, Loss G: 5.9736, Loss D: -0.0026
# Epoch 24, Loss G: 6.0129, Loss D: -0.0303
# Epoch 25, Loss G: 6.0717, Loss D: -0.0441
# Epoch 26, Loss G: 5.9611, Loss D: -0.0427
# Epoch 27, Loss G: 6.0608, Loss D: -0.0367
# Epoch 28, Loss G: 5.9844, Loss D: -0.0438
# Epoch 29, Loss G: 6.0165, Loss D: -0.0253
# Epoch 30, Loss G: 6.0775, Loss D: -0.0121
# Epoch 31, Loss G: 5.9402, Loss D: -0.0259
# Epoch 32, Loss G: 6.0535, Loss D: -0.0286
# Epoch 33, Loss G: 6.0224, Loss D: -0.0377
# Epoch 34, Loss G: 6.0642, Loss D: -0.0359
# Epoch 35, Loss G: 6.0163, Loss D: -0.0351
# Epoch 36, Loss G: 6.0954, Loss D: -0.0501
# Epoch 37, Loss G: 6.0198, Loss D: -0.0625
# Epoch 38, Loss G: 6.0009, Loss D: -0.0767
# Epoch 39, Loss G: 6.0661, Loss D: -0.0667
# Epoch 40, Loss G: 6.0330, Loss D: -0.0481
# Epoch 41, Loss G: 6.1298, Loss D: -0.0732
# Epoch 42, Loss G: 6.1248, Loss D: -0.0475
# Epoch 43, Loss G: 6.0601, Loss D: -0.0578
# Epoch 44, Loss G: 6.0821, Loss D: -0.1033
# Epoch 45, Loss G: 6.1109, Loss D: -0.0748
# Epoch 46, Loss G: 6.0585, Loss D: -0.0785
# Epoch 47, Loss G: 6.1017, Loss D: -0.0855
# Epoch 48, Loss G: 5.9943, Loss D: -0.0496
# Epoch 49, Loss G: 6.0403, Loss D: -0.0650
# Epoch 50, Loss G: 6.1659, Loss D: -0.0651

# %%
samples = ctgan.sample(len(data))

# %%
samples
# Out:
#           id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0    8860702         M       12.83        19.83          86.49      1145
# 1     893548         B       13.54        10.91          81.89     384.6
# 2    9112594         B       13.51        20.74          75.51     324.2
# 3     877501         B       11.27        19.38          91.43     408.8
# 4     869691         M       20.34        14.93          94.25     514.3
# ..       ...       ...         ...          ...            ...       ...
# 489  8910748         B       14.99        24.68          78.07     640.7
# 490    86355         M       13.96        22.53           74.2     366.8
# 491   891703         B       19.16         18.9          80.64     572.6
# 492   912193         M       13.69        19.97          85.98      1157
# 493  8913049         B        11.6        18.24          73.72     656.1
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  \
# 0           0.07987          0.05361         0.1128             0.09711
# 1           0.09425          0.05272        0.01123              0.0335
# 2           0.07026           0.0812         0.1367             0.04812
# 3            0.1128          0.06492        0.04608              0.0398
# 4           0.09996           0.1231           0.17             0.04083
# ..              ...              ...            ...                 ...
# 489         0.09933            0.072        0.02353             0.02704
# 490          0.0944          0.06526         0.0739             0.01105
# 491         0.09383           0.1145         0.2195             0.08811
# 492          0.1013          0.06679        0.01462             0.06463
# 493          0.1082           0.1147       0.008934             0.07404
#
#     symmetry_mean fractal_dimension_mean radius_se texture_se perimeter_se  \
# 0          0.2019                0.05976    0.3795       1.39        1.354
# 1          0.1815                 0.0696    0.1302     0.9429         1.34
# 2          0.2075                 0.0659    0.4709     0.9027        2.765
# 3          0.1992                0.07102    0.3093     0.6931        8.419
# 4          0.1945                0.06937    0.4727     0.9234        1.372
# ..            ...                    ...       ...        ...          ...
# 489        0.1167                0.06758    0.1707      0.948        3.357
# 490        0.2459                0.05266    0.5115      1.911        1.687
# 491        0.1819                 0.0558    0.2871     0.7975        7.247
# 492        0.1571                0.05407    0.3511      1.905        2.657
# 493        0.2175                  0.064    0.4222     0.7693        3.854
#
#     area_se smoothness_se compactness_se concavity_se concave points_se  \
# 0     69.06      0.006703        0.02493      0.09723          0.007373
# 1     11.86       0.00451        0.01203      0.03988           0.01196
# 2     22.97      0.006662        0.05374      0.05915          0.007711
# 3     30.57      0.008074        0.01957      0.01397           0.01254
# 4     22.79      0.009006        0.03082      0.01246           0.01639
# ..      ...           ...            ...          ...               ...
# 489   27.85      0.006809        0.01331      0.02176           0.01499
# 490   12.84      0.008875       0.009514      0.02631           0.00826
# 491    27.4      0.009769        0.02294      0.02623           0.01339
# 492   17.67       0.01037        0.01779      0.01603          0.008691
# 493   11.28      0.004731        0.01812      0.04665          0.004168
#
#     symmetry_se fractal_dimension_se radius_worst texture_worst  \
# 0       0.01669             0.002744        13.58         25.72
# 1       0.01865              0.00459        25.73         35.64
# 2       0.01332              0.00356        12.81         25.58
# 3       0.02158             0.001892        9.262         24.39
# 4       0.02309             0.003707        14.35         27.83
# ..          ...                  ...          ...           ...
# 489     0.01302             0.004261        16.86         29.15
# 490     0.01909            0.0008948        16.77          26.3
# 491     0.02158             0.002268        17.06         25.27
# 492     0.01467             0.004785        27.32         31.47
# 493     0.03357             0.002784        18.79         26.48
#
#     perimeter_worst area_worst smoothness_worst compactness_worst  \
# 0             97.67      466.7          0.08799             0.116
# 1             125.9       1021           0.1288            0.2444
# 2             86.04      483.1           0.1218             0.131
# 3             67.08      711.4           0.1025            0.1008
# 4             68.62      385.2           0.1701            0.2196
# ..              ...        ...              ...               ...
# 489           129.3       1540           0.1326           0.09669
# 490           90.67       1226           0.1168            0.1402
# 491           136.1       1298           0.1733            0.2809
# 492           152.2      518.1           0.1791            0.5955
# 493           63.34      749.9           0.1293            0.2735
#
#     concavity_worst concave points_worst symmetry_worst  \
# 0            0.3241               0.1642          0.544
# 1            0.6943               0.1205         0.2213
# 2            0.1673              0.06913         0.3679
# 3            0.3809              0.07911         0.3591
# 4             1.105              0.07966         0.3274
# ..              ...                  ...            ...
# 489          0.4589               0.1466         0.3198
# 490          0.2267              0.03002         0.2208
# 491          0.1242               0.1282         0.2383
# 492          0.5381               0.1555         0.2928
# 493          0.6121              0.09077          0.467
#
#     fractal_dimension_worst
# 0                   0.09772
# 1                    0.1155
# 2                   0.08194
# 3                   0.07609
# 4                   0.08911
# ..                      ...
# 489                  0.1204
# 490                 0.07712
# 491                  0.1191
# 492                 0.06435
# 493                  0.1014
#
# [494 rows x 32 columns]

# %%
samples.to_csv('./data/synthetic.csv', index=False)
